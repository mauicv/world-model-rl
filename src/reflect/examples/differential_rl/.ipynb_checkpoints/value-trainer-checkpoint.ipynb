# %%
import torch.nn as nn
from torch.nn import Module
import torch
import torch.nn.functional as F
import torch.distributions as D
from livelossplot import PlotLosses

from typing import Iterable, Optional
import math
import csv
import copy
from dataclasses import dataclass
import numpy as np
from collections import defaultdict
import tqdm

from reflect.data.differentiable_pendulum import DiffPendulumEnv
from reflect.models.rl.value_trainer import ValueGradTrainer, update_target_network
from reflect.models.rl.actor import Actor
from reflect.models.rl.value_critic import ValueCritic

# %%
actor = Actor(
    input_dim=3,
    output_dim=1,
    hidden_dim=64,
    num_layers=3,
    bound=2
)

critic = ValueCritic(
    state_dim=3,
    hidden_dim=64,
    num_layers=3
)

trainer = ValueGradTrainer(
    actor=actor,
    critic=critic,
    actor_lr=0.0005,
    critic_lr=0.0001,
    env=None
)

plotlosses = PlotLosses(
  groups={
    'return': ['return'],
    'last_reward': ['last_reward'],
    'policy_loss': ['policy_loss'],
    'critic_loss': ['critic_loss'],
    'entropy': ['entropy']
  },
)


batch_size = 32
env = DiffPendulumEnv()
env.set_seed(0)
logs = defaultdict(list)

# %%
torch.autograd.set_detect_anomaly(True)

for iteration in range(500_000 // batch_size):
    current_state, _ = env.reset(batch_size=batch_size)
    rewards = []
    dones = []
    states = []
    entropy = 0
    for _ in range(100):
        action_dist = trainer.actor(current_state)
        action = action_dist.rsample()
        action = action.squeeze(1)
        states.append(current_state)
        next_state, reward, done, _ = env.step(action)
        entropy = entropy + action_dist.entropy().mean()
        current_state = next_state
        rewards.append(reward)
        dones.append(done)

    rewards = torch.stack(rewards, dim=1)
    states = torch.stack(states, dim=1)
    dones = torch.stack(dones, dim=1).to(torch.float32)

    target_values = trainer.compute_values(
        state_samples=states,
        reward_samples=rewards,
        done_samples=dones
    )

    critic_loss = trainer.critic_loss(
        state_samples=states,
        target_values=target_values
    )
    trainer.critic_optim.backward(critic_loss, retain_graph=True)
    trainer.critic_optim.update_parameters()

    policy_loss = trainer.policy_loss(target_values)
    actor_loss = policy_loss - trainer.entropy_weight * entropy
    trainer.actor_optim.backward(actor_loss)
    trainer.actor_optim.update_parameters()

    update_target_network(trainer.target_critic, trainer.critic)

    if iteration % 10 == 0:
        logs["return"].append(actor_loss.detach().item())
        logs["last_reward"].append(rewards[:, -1].detach().mean().item())
        logs["policy_loss"].append(policy_loss.detach().mean().item())
        logs["critic_loss"].append(critic_loss.detach().mean().item())
        logs["entropy"].append(entropy.detach().item())

        data = {
            'return': logs['return'][-1],
            'last_reward': logs['last_reward'][-1],
            'policy_loss': logs['policy_loss'][-1],
            'critic_loss': logs['critic_loss'][-1],
            'entropy': logs['entropy'][-1]
        }

        plotlosses.update(data)
        plotlosses.send()
# Out:
# critic_loss
# 	critic_loss      	 (min: 4188.163, max: 4719.608, cur: 4188.163)
# entropy
# 	entropy          	 (min:   70.454, max:   75.458, cur:   75.458)
# last_reward
# 	last_reward      	 (min:   -8.128, max:   -6.710, cur:   -8.128)
# policy_loss
# 	policy_loss      	 (min:   85.549, max:   90.127, cur:   85.549)
# return
# 	return           	 (min:   85.542, max:   90.120, cur:   85.542)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      21 states = torch.stack(states, dim=1)
#      22 dones = torch.stack(dones, dim=1).to(torch.float32)
# ---> 24 target_values = trainer.compute_values(
#      25     state_samples=states,
#      26     reward_samples=rewards,
#      27     done_samples=dones
#      28 )
#      30 critic_loss = trainer.critic_loss(
#      31     state_samples=states,
#      32     target_values=target_values
#      33 )
#      34 trainer.critic_optim.backward(critic_loss, retain_graph=True)
#
# File ~/development/personal/world-model-rl/src/reflect/models/rl/value_trainer.py:136, in ValueGradTrainer.compute_values(self, state_samples, reward_samples, done_samples)
#     134 targets = []
#     135 for i in range(h):
# --> 136     rollout_targets = self.compute_value_target(
#     137         target_state_values=target_state_values[:, i:, :],
#     138         states=state_samples[:, i:, :],
#     139         rewards=reward_samples[:, i:, :],
#     140         dones=done_samples[:, i:, :],
#     141     )
#     142     targets.append(rollout_targets)
#     143 target_values = torch.stack(targets, dim=1)
#
# File ~/development/personal/world-model-rl/src/reflect/models/rl/value_trainer.py:94, in ValueGradTrainer.compute_value_target(self, target_state_values, rewards, states, dones)
#      92 _, big_h, *_ = states.shape
#      93 for k in range(1, big_h - 1):
# ---> 94     val = self.compute_rollout_value(
#      95         target_state_values=target_state_values,
#      96         rewards=rewards,
#      97         states=states,
#      98         dones=dones,
#      99         k=k
#     100     )
#     101     val_sum = val_sum + self.lam**(k - 1) * val
#     102 final_val = self.compute_rollout_value(
#     103     target_state_values=target_state_values,
#     104     rewards=rewards,
#    (...)
#     107     k=big_h
#     108 )
#
# File ~/development/personal/world-model-rl/src/reflect/models/rl/value_trainer.py:82, in ValueGradTrainer.compute_rollout_value(self, target_state_values, rewards, states, dones, k)
#      72 R = (
#      73     self.gamma_rollout[:h][None, :, None]
#      74     * rewards[:, :h]
#      75     * (1 - dones[:, :h])
#      76 )
#      77 final_values = (
#      78     self.gamma_rollout[h]
#      79     * target_state_values[:, [h]].detach()
#      80     * (1 - dones[:, [h]])
#      81 )
# ---> 82 return R.sum(1) + final_values[:, 0, :]
#
# File ~/development/personal/world-model-rl/venv/lib/python3.10/site-packages/torch/fx/traceback.py:68, in format_stack()
#      65     return [current_meta.get("stack_trace", "")]
#      66 else:
#      67     # fallback to traceback.format_stack()
# ---> 68     return traceback.format_list(traceback.extract_stack()[:-1])
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/traceback.py:39, in format_list(extracted_list)
#      27 def format_list(extracted_list):
#      28     """Format a list of tuples or FrameSummary objects for printing.
#      29
#      30     Given a list of tuples or FrameSummary objects as returned by
#    (...)
#      37     whose source text line is not None.
#      38     """
# ---> 39     return StackSummary.from_list(extracted_list).format()
#
# File /opt/local/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/traceback.py:440, in StackSummary.format(self)
#     438     continue
#     439 row = []
# --> 440 row.append('  File "{}", line {}, in {}\n'.format(
#     441     frame.filename, frame.lineno, frame.name))
#     442 if frame.line:
#     443     row.append('    {}\n'.format(frame.line.strip()))
#
# KeyboardInterrupt:
